# %%
from main import *

# %%
player1=Player()
player2=Player()
player3=Player()

# %%
for i in range(100000):
    play(player1,Player())
    
print(len(player1.playbook))
plotWinRatio(player1)
# Out:
# 28

# %%
for box in player1.playbook:
    box.heatmap()

# %%
stages = play(player1,player1)

for stage in stages:
    stage.visualize()

# %%
stages = play(player1,player1)

for stage in stages:
    stage.visualize()
